# %%
# %run ex1.py
# Out:
# 4
# Epoch 1/2
# 41765/41765 [==============================] - 5s 112us/step - loss: 0.6990 - acc: 0.4958
# Epoch 2/2
# 41765/41765 [==============================] - 4s 99us/step - loss: 0.6975 - acc: 0.5007
# Average score : 8.0
# Median score : 8.0
# Average score : 8.0
# Median score : 8.0
# Average score : 8.333333333333334
# Median score : 8.0
# Average score : 9.25
# Median score : 8.5
# Average score : 9.4
# Median score : 9.0
# Average score : 9.333333333333334
# Median score : 9.0
# Average score : 9.285714285714286
# Median score : 9.0
# Average score : 9.25
# Median score : 9.0
# Average score : 9.444444444444445
# Median score : 9.0
# Average score : 9.4
# Median score : 9.0
# Average score : 9.454545454545455
# Median score : 9.0
# Average score : 9.416666666666666
# Median score : 9.0
# Average score : 9.538461538461538
# Median score : 9.0
# Average score : 9.571428571428571
# Median score : 9.0
# Average score : 9.666666666666666
# Median score : 9.0
# ...

# %%
model.summary()

# %%
obs, *l = env.step(0)

# %%
obs

# %%
obs.shape

# %%
np.argmax(model.predict(obs.reshape(1,4)))

# %%
obs1, *l = env.step(0)

# %%
np.stack([obs, obs1]).shape

# %%
model.predict(np.stack([obs]))
